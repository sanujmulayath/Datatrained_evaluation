# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# We need to get the details on what is each column and how they contribute in real world for baseball

# %% [markdown]
# W  - Win
#
# R  - Runs
#
# AB - At bats (At-Bat comes when a batter reaches base via a fielder's choice, hit or an error)
#
# H  - Hit (A hit occurs when a batter strikes the baseball into fair territory and reaches base without doing so via an error or a fielder's choice)
#
# 2B - Double (Second baseman)
#
# 3B - Triple (Third baseman)
#
# HR - Home Run (A home run occurs when a batter hits a fair ball and scores on the play without being put out or without the benefit of an error)
#
# BB - A walk occurs when a pitcher throws four pitches out of the strike zone, none of which are swung at by the hitter.
#
# SO - Strikeouts: The number of times a player strikes out while at bat.
#
# SB - Bases Stolen: The total number of bases a player has stolen as a baserunner.
#
# RA - Run average, pace at which runs are scored.
#
# ER - An earned run is any run that scores against a pitcher without the benefit of an error or a passed ball
#
# ERA- Earned run average represents the number of earned runs a pitcher allows per nine innings
#
# CG - Act of a pitcher pitching an entire game without the benefit of a relief pitcher
#
# SHO- Shutout refers to the act by which a single pitcher pitches a complete game.
#
# SV - A save is awarded to the relief pitcher who finishes a game for the winning team
#
# E  - E stands for errors commited.

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# ### Checking for Na values

# %%
df.isna().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No na values and hence we can proceed further

# %% [markdown]
# ### Checking for datatypes.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Every data values are in interger format so we will not have to work on that as well.

# %% [markdown]
# ## EDA

# %% [markdown]
# Checking the details of normalisation in the output variabale.

# %%
df['W'].skew()
# Out:
# 0.047088688953686085

# %%
# histogram
sns.histplot(df['W'], kde=True)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# We are able to see here that the output variables are normalaly distributed. Moving ahead with other variables

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
cols= ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E']
for i in cols:
    sns.distplot(df[i], kde = True)
    plt.show()

# %% [markdown]
# Boxplot

# %%
#cols is already defined above
for i in cols:
    sns.set_theme(style="whitegrid")
    ax = sns.boxplot(x=df[i])
    plt.show()

# %% [markdown]
# Huge difference is only there in Runs, hence we will be removing outliers later.

# %% [markdown]
# Checking skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Looking at the skewness of the data and keeping the range from -0.5 to 0.5 we see here that there are a few columns like Runs, H, CGSV, E, etc so we might need to scale the whole data in the later part.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Total number of rows: 30
#
# W  - Mean: 80.96
#
#      Median: 81.0
#
#      Max:100
#
# R  - Mean: 688.2
#
#      Median:689.0
#
#      Max:891.0
#
# AB - Mean: 5516.266667
#
#      Median: 5510.000000
#
#      Max:5649.000000
#
# H  - Mean: 1403.533333
#
#      Median:1382.500000
#
#      Max:1515.000000
#
# 2B - Mean: 274.733333
#
#      Median:275.500000
#
#      Max:308.000000
#
# 3B - Mean: 31.300000
#
#      Median:31.000000
#
#      Max:49.000000
#
# HR - Mean: 163.633333
#
#      Median:158.500000
#
#      Max:232.000000
#
# BB - Mean: 469.100000
#
#      Median:473.000000
#
#      Max:570.000000
#
# SO - Mean:1248.20000
#
#      Median:1261.50000
#
#      Max:1518.00000
#
# SB - Mean: 83.500000
#
#      Median:83.500000
#
#      Max:134.000000
#
# RA - Mean: 688.233333
#
#      Median:695.500000
#
#      Max:844.000000
#
# ER - Mean: 635.833333
#
#      Median:644.500000
#
#      Max:799.000000
#
# ERA- Mean: 3.956333
#
#      Median:4.025000
#
#      Max:5.040000
#
# CG - Mean: 3.466667
#
#      Median:3.000000
#
#      Max:11.000000
#
# SHO- Mean: 11.300000
#
#      Median:12.000000
#
#      Max:21.000000
#
# SV - Mean: 43.066667
#
#      Median:42.000000
#
#      Max:62.000000
#
# E  - Mean: 94.333333
#
#      Median:91.000000
#
#      Max:126.000000

# %%
corr=df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. If the team is committing error, there is a chance that they do not win much.
# 2. If the team is having more saves, there is a chance that the win goes higher.
# 3. If shutouts are more, the team winning percentage is more.
# 4. If single pitcher is pitching the ball, there is a chanace that the team wins.
# 5. If Earned Run average or earned runs are more,Run average the team might loose the game.
# 6. If bases are stolen, the team might loose the game.
# 7. If number of strike outs and walks and Home Runs are more, there is a high chance the team can win.
# 8. However with the number of triples, the chances of winning reduces.
# 9. With number of double and hits, the chances of wininng increases.
# 10. The more, the runs, the more team can win.

# %% [markdown]
# As we got a basic idea on whata might affect the winning or loosing part of the game, we can move ahead with standardising the data to perform better. However, we will keep them in a separate file so that we can get a difference between the standardised and non standardised data.

# %% [markdown]
# ## Checking z score before splitting.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
dfn = df[(z<3).all(axis = 1)]

# %%
print('size before removing ourlier is',df.shape)
print('size after removing outliers are',dfn.shape)
# Out:
# size before removing ourlier is (30, 17)
# size after removing outliers are (29, 17)

# %% [markdown]
# so only 1 outlier removed which we can consider as this outlier might pull the mean and make a difference in the data.

# %% [markdown]
# ## Splitting the data.

# %%
dfn_x = df.drop(columns='W')
dfn_y = df['W']

# %%
dfn_y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# Working on to reduce the skewness of the data

# %%
# for i in dfn_x.columns:
 #   if dfn_x[i].skew()>0.5:
  #      dfn_x[i] = np.cbrt(dfn_x[i])
   # if dfn_x[i].skew()<-0.5:
    #    dfn_x[i] = np.cbrt(dfn_x[i])

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Tried skewing data, however that is not making much difference in the skewness as one or the other columns skewss is getting over -0.5 or 0.5 and because there is not much skewness in the whole data,avoiding this step.

# %% [markdown]
# ## Standardisation

# %%
col_names = list(dfn_x.columns)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dfn_x = scaler.fit_transform(dfn_x)#converting back to dataframe
dfn_x=pd.DataFrame(dfn_x,columns=col_names)
dfn_x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
dfn_x.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.697630  0.913883 -0.666234 -0.505110 -0.506955 -0.539806 -0.814629
# 1  0.154878 -0.601826  0.165971  0.248930  0.254598 -0.539806  0.172800
# 2 -0.893982  0.111449 -0.680339 -0.751623 -0.641347  2.772641 -0.320914
# 3 -0.168602 -0.690985  0.180076  0.103922  0.053010  1.300442 -0.567771
# 4  0.105866 -0.022290  1.618803  1.597501  1.531318  1.300442  0.172800
#
#          SV         E
# 0  1.671607 -0.461470
# 1  0.249879 -0.607197
# 2 -0.654856 -1.117242
# ...

# %% [markdown]
# ## Modelling

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(dfn_x,dfn_y, test_size=.30,random_state=25)

# %%
x_test.shape
# Out:
# (9, 16)

# %% [markdown]
# Not using for loop for test and random state as we usually work on getting the best random state and use that for other models as well, however there is a possibility the the random value chanage with the model we use to get the best random state or test size hence not using that and assuming mostly used 30 7- split for test and a random value for random state as I presume that it might not bring a big difference in the data.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
lr = LinearRegression()
knr = KNeighborsRegressor()
dtr = DecisionTreeRegressor()
svr = SVR()
rfr = RandomForestRegressor()
ls = Lasso()
rd = Ridge()
eln = ElasticNet()

# %%
model=[lr,knr,dtr,svr,rfr,ls,rd,eln]
for m in model:
    print('The model is: ',m)
    m.fit(x_train,y_train)
    predict=m.predict(x_test)
    pred_train=m.predict(x_train)
    print('R2_score for the training : ',r2_score(y_train,pred_train))
    print('R2 score for the model is: ',r2_score(y_test,predict))
    print('Mean absolute error is: ',mean_absolute_error(y_test,predict))
    print('Mean squared error is: ',mean_squared_error(y_test,predict))
    print('\n\n')
# Out:
# The model is:  LinearRegression()
# R2_score for the training :  0.9945608590629402
# R2 score for the model is:  -0.33742389044458476
# Mean absolute error is:  8.067538495554777
# Mean squared error is:  146.22501202194127
#
#
#
# The model is:  KNeighborsRegressor()
# R2_score for the training :  0.7420998437069044
# R2 score for the model is:  0.4347967479674798
# Mean absolute error is:  6.844444444444442
# Mean squared error is:  61.79555555555554
#
#
#
# The model is:  DecisionTreeRegressor()
# R2_score for the training :  1.0
# R2 score for the model is:  0.4695121951219512
# Mean absolute error is:  6.222222222222222
# Mean squared error is:  58.0
#
#
#
# The model is:  SVR()
# R2_score for the training :  0.2540868487241631
# R2 score for the model is:  0.006995658001864746
# Mean absolute error is:  8.600018285983886
# Mean squared error is:  108.56847472512945
#
#
#
# The model is:  RandomForestRegressor()
# R2_score for the training :  0.9410250321779903
# ...

# %% [markdown]
# Testing once for the data which is not standardised to get an exact figure if standardisatiion and removing outliers has helpde or not.

# %%
#df_x=df.drop(columns='W')
#df_y=df['W']
#x_t,x_te,y_t, y_te=train_test_split(df_x,df_y, test_size=.30,random_state=25)
#model=[lr,knr,dtr,svr,rfr,ls,rd,eln]
#for m in model:
#    print('The model is: ',m)
#    m.fit(x_t,y_t)
#    predict=m.predict(x_te)
#    print('R2 score for the model is: ',r2_score(y_te,predict))
#    print('Mean absolute error is: ',mean_absolute_error(y_te,predict))
#    print('Mean squared error is: ',mean_squared_error(y_te,predict))
#    print('\n\n')

# %% [markdown]
# Comparitively, we see here that in some models, the once we have predicted after splitting is performing better on lasso and ridge etc.. so we will continue with the same data that we have already and complete the cross validation check.

# %%
#train_accuracy = r2_score(y_train, pred_train)
#test_accuracy = r2_score(y_test, predict)

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
model = [lr, knr, dtr, svr, rfr, ls, rd, eln]
for m in model:
    print('The model is: \n',m)
    for j in range (2,10):
        train_accuracy = r2_score(y_train, pred_train)
        test_accuracy = r2_score(y_test, predict)
        cv_score = cross_val_score(m, dfn_x, dfn_y, cv = j)
        cv_mean = cv_score.mean()
        print(f'At cross fold {j} the cv score is {cv_mean}')
        print('\n\n')
# Out:
# The model is:
#  LinearRegression()
# At cross fold 2 the cv score is -0.9911855504647521
#
#
#
# At cross fold 3 the cv score is 0.22588460167738647
#
#
#
# At cross fold 4 the cv score is 0.2495216665436925
#
#
#
# At cross fold 5 the cv score is 0.04075540667455595
#
#
#
# At cross fold 6 the cv score is 0.25153530937186797
#
#
#
# At cross fold 7 the cv score is 0.389080464428948
#
#
#
# At cross fold 8 the cv score is 0.3193702210966787
#
#
#
# At cross fold 9 the cv score is -4.809084120395504
#
#
#
# The model is:
#  KNeighborsRegressor()
# At cross fold 2 the cv score is -0.11218368314116178
#
#
#
# At cross fold 3 the cv score is 0.45679585084509333
#
#
#
# At cross fold 4 the cv score is 0.44860939144862244
#
#
#
# At cross fold 5 the cv score is -0.1636431681468944
#
#
#
# At cross fold 6 the cv score is 0.4465713165003682
#
#
#
# At cross fold 7 the cv score is 0.15711680139152542
#
#
#
# At cross fold 8 the cv score is 0.26962333565211966
#
#
#
# ...

# %% [markdown]
# Looking at the data, we see here that Lasso is having the best accuracy.

# %%
ls.fit(x_train, y_train)
a = ls.score(x_train, y_train)
pred_train = ls.predict(x_train)
pred_test_ls = ls.predict(x_test)

# %%
plt.figure(figsize = (8,6))
plt.scatter(x = y_test, y = pred_test_ls, color = 'r')
plt.plot(y_test, y_test, color = 'b')
plt.xlabel('Actual Score: ', fontsize = 14)
plt.ylabel('Predicted Score: ', fontsize = 14)
plt.title('Random forest', fontsize = 18)
plt.show()

# %% [markdown]
# We see here almost all the daata are lying towards the predicted line.

# %% [markdown]
# ## Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
alpha=[0.001,0.01,0.1,1,10,100]
param_grid=dict(alpha=alpha)

grid=GridSearchCV(estimator=ls,param_grid=param_grid,scoring='r2', verbose=1, n_jobs=1)
grid_result = grid.fit(x_train, y_train)

print('Best Score: ', grid_result.best_score_)
print('Best Params: ', grid_result.best_params_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best Score:  0.6707021264023276
# Best Params:  {'alpha': 1}

# %%
lasso=Lasso(alpha=1)

# %%
lasso.fit(x_train, y_train)
lasso.score(x_train, y_train)
predlasso = lasso.predict(x_test)
data = [predlasso, y_test]
pd.DataFrame(data, index = ['Predicted', 'Actual'])
# Out:
#                    0          1          2         3          4          5  \
# Predicted  73.724482  88.595069  84.897027  79.14204  66.588972  82.310615
# Actual     64.000000  86.000000  81.000000  78.00000  63.000000  79.000000
#
#                    6          7          8
# Predicted  80.946812  78.405225  85.825726
# Actual     88.000000  68.000000  95.000000

# %%
print('Errors:')
print('\n')
print('Mean absolute error: ', mean_absolute_error(y_test,predlasso))
print('Mean squared error: ', mean_squared_error(y_test,predlasso))
print('Root mean squared error: ', np.sqrt(mean_squared_error(y_test,predlasso)))
print('\n')
print('R2 Score: ', r2_score(y_test,predlasso))
# Out:
# Errors:
#
#
# Mean absolute error:  5.654543479193277
# Mean squared error:  42.64615244968707
# Root mean squared error:  6.530402165999202
#
#
# R2 Score:  0.6099437275943256

# %% [markdown]
# We finalise the lasso model with an R2 score of 60.99% for the data.

# %% [markdown]
# ## Saving the model

# %%
import joblib

# %%
joblib.dump(lasso, 'baseball_lasso.obj')
# Out:
# ['baseball_lasso.obj']
